# %%
# %pip install pandas
# %pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\12dem\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\12dem\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

train = pd.read_csv(r'C:\Users\12dem\OneDrive\Desktop\Mtech_assignments\ML\bike_train.csv')
test = pd.read_csv(r'C:\Users\12dem\OneDrive\Desktop\Mtech_assignments\ML\bike_test.csv')

# %%
test
# Out:
#               datetime  season  holiday  workingday  weather       temp  \
# 0      05-06-2012 5:00       2        0           1        3  19.680000
# 1     19-03-2011 19:00       1        0           0        1  18.040000
# 2      02-04-2012 6:00       2        0           1        1  13.885038
# 3     13-07-2012 20:00       3        0           1        1  30.340000
# 4     09-11-2011 19:00       4        0           1        1  18.040000
# ...                ...     ...      ...         ...      ...        ...
# 2608   07-11-2012 5:00       4        0           1        2  11.480000
# 2609  16-12-2011 05:00       4        0           1        1  19.680000
# 2610  14-01-2011 23:00       1        0           1        2   7.380000
# 2611  19-02-2011 09:00       1        0           0        1  17.597541
# 2612  17-03-2012 05:00       1        0           0        2  17.220000
#
#           atemp  humidity  windspeed
# 0     23.485000        82  11.001400
# 1     21.970000        33  19.001200
# 2     16.246640        68  29.526460
# 3     33.335000        48   8.998100
# 4     21.970000        72   7.001500
# ...         ...       ...        ...
# 2608  12.880000        52  22.002800
# 2609  23.485000        44  26.002700
# 2610  12.120000        55   0.000000
# 2611  21.284318        15  44.790992
# 2612  21.210000        94   6.003200
#
# [2613 rows x 9 columns]

# %%
train
# Out:
#                   datetime  season  holiday  workingday  weather      temp  \
# 0       2012-07-15 7:00:00       3        0           0        1  28.70000
# 1      2012-08-14 15:00:00       3        0           1        1  33.62000
# 2       2011-02-06 6:00:00       1        0           0        1  10.66000
# 3      2012-05-06 17:00:02       2        0           0        2  26.42506
# 4       2012-01-09 2:00:00       1        0           1        1   9.84000
# ...                    ...     ...      ...         ...      ...       ...
# 10445  2012-10-14 13:00:00       4        0           0        1  26.24000
# 10446  2011-03-12 22:00:00       1        0           0        1  14.76000
# 10447   2011-04-07 6:00:00       2        0           1        1  13.12000
# 10448   2012-08-19 9:00:00       3        0           0        2  27.06000
# 10449   2012-01-15 0:00:00       1        0           0        1   6.56000
#
#            atemp  humidity  windspeed  casual  registered  count
# 0      33.335000        79   6.003200      17          30     47
# 1      37.880000        46  15.001300      84         199    283
# 2      12.880000        60  15.001300       0           1      1
# 3      30.566166        61   9.512288     198         330    531
# 4      12.120000        56   8.998100       2           3      5
# ...          ...       ...        ...     ...         ...    ...
# 10445  31.060000        41  30.002600     218         401    619
# 10446  18.940000        71   0.000000       7          56     63
# 10447  15.150000        81  16.997900       5          59     64
# 10448  31.060000        74   0.000000      86         184    270
# 10449   6.820000        47  22.002800       9          50     59
#
# [10450 rows x 12 columns]

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10450 entries, 0 to 10449
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10450 non-null  object
#  1   season      10450 non-null  int64
#  2   holiday     10450 non-null  int64
#  3   workingday  10450 non-null  int64
#  4   weather     10450 non-null  int64
#  5   temp        10450 non-null  float64
#  6   atemp       10450 non-null  float64
#  7   humidity    10450 non-null  int64
#  8   windspeed   10450 non-null  float64
#  9   casual      10450 non-null  int64
#  10  registered  10450 non-null  int64
#  11  count       10450 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 979.8+ KB
# None

# %%
print("Train shape:", train.shape)
print("Test shape:", test.shape)
print(train.head().to_string(index=False))
# Out:
# Train shape: (10450, 12)
# Test shape: (2613, 9)
#            datetime  season  holiday  workingday  weather     temp     atemp  humidity  windspeed  casual  registered  count
#  2012-07-15 7:00:00       3        0           0        1 28.70000 33.335000        79   6.003200      17          30     47
# 2012-08-14 15:00:00       3        0           1        1 33.62000 37.880000        46  15.001300      84         199    283
#  2011-02-06 6:00:00       1        0           0        1 10.66000 12.880000        60  15.001300       0           1      1
# 2012-05-06 17:00:02       2        0           0        2 26.42506 30.566166        61   9.512288     198         330    531
#  2012-01-09 2:00:00       1        0           1        1  9.84000 12.120000        56   8.998100       2           3      5

# %%
print(train.dtypes)
print(train.isnull().sum())
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
print(train.describe().to_string(index=False))
# Out:
#       season      holiday   workingday      weather         temp        atemp     humidity    windspeed       casual   registered        count
# 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000 10450.000000
#     2.507943     0.028804     0.675694     1.413876    20.191700    23.605793    61.924211    12.765259    35.869091   154.511675   190.410526
#     1.116946     0.167263     0.468137     0.632258     7.792683     8.478045    19.245193     8.102821    49.629436   150.861267   181.038755
#     1.000000     0.000000     0.000000     1.000000     0.820000     0.760000     0.000000     0.000000     0.000000     0.000000     1.000000
#     2.000000     0.000000     0.000000     1.000000    13.940000    16.665000    47.000000     7.001500     4.000000    35.000000    42.000000
#     3.000000     0.000000     1.000000     1.000000    20.500000    24.240000    62.000000    12.450050    16.000000   117.000000   143.000000
#     4.000000     0.000000     1.000000     2.000000    26.240000    31.060000    77.000000    16.997900    49.000000   221.000000   283.000000
#     4.000000     1.000000     1.000000     4.000000    41.000000    45.455000   100.000000    56.996900   367.000000   886.000000   977.000000

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\12dem\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\12dem\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\12dem\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\12dem\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

train_info = pd.DataFrame({
    "dtype": train.dtypes.astype(str),
    "missing": train.isnull().sum(),
    "unique": train.nunique().replace({0: np.nan})
})
display(train_info)
# Out:
#               dtype  missing  unique
# datetime     object        0   10450
# season        int64        0       4
# holiday       int64        0       2
# workingday    int64        0       2
# weather       int64        0       4
# temp        float64        0    1801
# atemp       float64        0    1815
# humidity      int64        0      92
# windspeed   float64        0    1676
# casual        int64        0     296
# registered    int64        0     716
# count         int64        0     817

# %%
train['datetime'] = pd.to_datetime(train['datetime'], format="mixed")

test['datetime'] = pd.to_datetime(test['datetime'], format="%d-%m-%Y %H:%M")

train.head()
# Out:
#              datetime  season  holiday  workingday  weather      temp  \
# 0 2012-07-15 07:00:00       3        0           0        1  28.70000
# 1 2012-08-14 15:00:00       3        0           1        1  33.62000
# 2 2011-02-06 06:00:00       1        0           0        1  10.66000
# 3 2012-05-06 17:00:02       2        0           0        2  26.42506
# 4 2012-01-09 02:00:00       1        0           1        1   9.84000
#
#        atemp  humidity  windspeed  casual  registered  count
# 0  33.335000        79   6.003200      17          30     47
# 1  37.880000        46  15.001300      84         199    283
# 2  12.880000        60  15.001300       0           1      1
# 3  30.566166        61   9.512288     198         330    531
# 4  12.120000        56   8.998100       2           3      5

# %%
for df in (train, test):
    df['hour'] = df['datetime'].dt.hour
    df['weekday'] = df['datetime'].dt.weekday  
    df['month'] = df['datetime'].dt.month
    df['year'] = df['datetime'].dt.year

# %%
#Dropping the datetime cloumn as it is no longer required after extracting the data from it
train = train.drop(columns=["datetime"],axis=1)
test = test.drop(columns=["datetime"],axis=1)

#Also dropping the casual and registered cloumns as they are (casual+registered = count)
train = train.drop(columns=["casual", "registered"],axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(11, 11)) 
sns.heatmap(train.corr('pearson'), annot=True, fmt=".2f", cmap="coolwarm",vmin=-1, vmax=1)
plt.show()

# %%
#Bar plot for weekday wise monthly distribution of counts

weekday_palette = sns.color_palette("tab10", 7) #just a custom palette


fig,ax1=plt.subplots(figsize=(13,7))
sns.barplot(x='month',y='count',data=train[['month','count','weekday']],hue='weekday',ax=ax1,palette=weekday_palette)
ax1.set_title('count on weekday based on months')
plt.show()

fig,ax1=plt.subplots(figsize=(13,7))
sns.pointplot(data=train, x='hour', y='count', hue='weekday', palette=weekday_palette)

fig,ax=plt.subplots(figsize=(13,7))
sns.barplot(data=train,x='holiday',y='count',hue='season',palette=weekday_palette)
ax.set_title('count on holidays')
plt.show()
# Out:
# C:\Users\12dem\AppData\Local\Temp\ipykernel_7264\1686374388.py:15: UserWarning: The palette list has more values (7) than needed (4), which may not be intended.
#   sns.barplot(data=train,x='holiday',y='count',hue='season',palette=weekday_palette)

# %%
plt.figure(figsize=(13,7))
plt.scatter(train['temp'], train['count'], s=6)
plt.title("Temp vs Count")
plt.xlabel("Temperature")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(13,7))
plt.scatter(train['atemp'], train['count'], s=6)
plt.title("ATemp vs Count")
plt.xlabel("ATemperature")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(13,7))
plt.scatter(train['humidity'], train['count'], s=6)
plt.title("humidity vs Count")
plt.xlabel("humidity")
plt.ylabel("Count")
plt.show()


plt.figure(figsize=(13,7))
plt.scatter(train['windspeed'], train['count'], s=6)
plt.title("Windspeed vs Count")
plt.xlabel("Windspeed")
plt.ylabel("Count")
plt.show()

# %%
#Boxplot for count outliers
sns.boxplot(data=train[['count']])
ax.set_title('count outliers')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

features = ['season','holiday',	'workingday','weather','temp','atemp','humidity','windspeed','hour','weekday','month','year']
x=train[features]
y=train['count']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

LR_model = LinearRegression()
LR_model.fit(x_train, y_train)
pred_LR = LR_model.predict(x_test)

# %%
def rmsle(y_true, y_pred):
    y_pred = np.maximum(0, y_pred)   
    return np.sqrt(np.mean((np.log1p(y_pred) - np.log1p(y_true))**2))

# %%
print("Linear Regression RMSLE:", rmsle(y_test, pred_LR))
# Out:
# Linear Regression RMSLE: 1.2884296003280722

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)

X_train_poly = poly.fit_transform(x_train)
X_val_poly = poly.transform(x_test)

lr_poly = LinearRegression()
lr_poly.fit(X_train_poly, y_train)
pred_lr_poly = lr_poly.predict(X_val_poly)

print("Poly Linear Regression RMSLE:", rmsle(y_test, pred_lr_poly))
# Out:
# Poly Linear Regression RMSLE: 1.390131876722038

# %%
scaler = StandardScaler(with_mean=False)
X_train_poly_scaled = scaler.fit_transform(X_train_poly)
X_val_poly_scaled = scaler.transform(X_val_poly)

ridge = Ridge(alpha=1.0)
ridge.fit(X_train_poly_scaled, y_train)
pred_ridge = ridge.predict(X_val_poly_scaled)

print("Ridge RMSLE:", rmsle(y_test, pred_ridge))
# Out:
# Ridge RMSLE: 1.3665140665505537

# %%
lasso = Lasso(alpha=0.001, max_iter=10000)
lasso.fit(X_train_poly_scaled, y_train)
pred_lasso = lasso.predict(X_val_poly_scaled)
pred_lasso = np.maximum(0, pred_lasso)


print("Lasso RMSLE:", rmsle(y_test, pred_lasso))
# Out:
# Lasso RMSLE: 1.3676210670517959
# c:\Users\12dem\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.830e+07, tolerance: 2.739e+04
#   model = cd_fast.enet_coordinate_descent(

# %%
results = pd.DataFrame({
    'Model': ['Linear', 'Poly Linear', 'Ridge', 'Lasso'],
    'RMSLE': [
        rmsle(y_test, pred_LR),
        rmsle(y_test, pred_lr_poly),
        rmsle(y_test, pred_ridge),
        rmsle(y_test, pred_lasso)
    ]
})
results
# Out:
#          Model     RMSLE
# 0       Linear  1.288430
# 1  Poly Linear  1.390132
# 2        Ridge  1.366514
# 3        Lasso  1.367621
